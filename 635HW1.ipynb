# %% [markdown]
# <a href="https://colab.research.google.com/github/JohnDane8181/CloneToDesktop/blob/master/635HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from google.colab import drive
#drive.mount('/content/my drive')
# !python -m pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.7.12, pytest-3.6.4, py-1.11.0, pluggy-0.7.1
# rootdir: /content, inifile:
# plugins: typeguard-2.7.1
# collected 7 items
#
# submission_test.py ..FFFFF                                               [100%]
#
# =================================== FAILURES ===================================
# ______________________________ test_dict_of_lists ______________________________
#
#     def test_dict_of_lists():
#         example = [('yellow', 1), ('blue', 2), ('yellow', 3), ('blue', 4), ('red', 1)]
# >       assert submission.dict_of_lists(example) == {'yellow': [1, 3], 'blue': [2, 4], 'red': [1]}
# E       AssertionError: assert None == {'blue': [2, 4], 'red': [1], 'yellow': [1, 3]}
# E        +  where None = <function dict_of_lists at 0x7f9675a44e60>([('yellow', 1), ('blue', 2), ('yellow', 3), ('blue', 4), ('red', 1)])
# ...
